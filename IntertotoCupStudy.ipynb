# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/AbstractClassesAndInterfaces/blob/master/IntertotoCupStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing all the necessary libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, FFMpegWriter
import seaborn as sns

# %%
# Importing the dataset:
uefa_competitions = pd.ExcelFile('UEFA Competitions finals.xlsx')
uic = pd.read_excel(uefa_competitions, 'UEFA Intertoto Cup finals')

# Displaying the last 5 champions:
uic.tail()
# Out:
#      Season Winners country           Winners Score (1st leg) Score (2nd leg)  \
# 65  2005-06          France         Marseille             0–2             5–1
# 66  2005-06         Germany      Hamburger SV             1–0             0–0
# 67  2006-07         England  Newcastle United             1–1             3–0
# 68  2007-08         Germany      Hamburger SV             1–1             4–0
# 69  2008-09        Portugal             Braga             2–0             3–0
#
#              Runners-up Runners-up country       Venue (1st leg)  \
# 65  Deportivo La Coruña              Spain                Riazor
# 66             Valencia              Spain    HSH Nordbank Arena
# 67           Lillestrøm             Norway        St James' Park
# 68       Dacia Chișinău            Moldova  Stadionul Republican
# 69            Sivasspor             Turkey               4 Eylül
#
#     Host city (1st leg) Host country (1st leg)             Venue (2nd leg)  \
# ...

# %%
# Displaying the number of rows and columns in the dataset:
uic.shape
# Out:
# (70, 16)

# %%
# Displaying the datatypes presented in the columns:
uic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Season                  70 non-null     object
#  1   Winners country         70 non-null     object
#  2   Winners                 70 non-null     object
#  3   Score (1st leg)         41 non-null     object
#  4   Score (2nd leg)         38 non-null     object
#  5   Runners-up              41 non-null     object
#  6   Runners-up country      41 non-null     object
#  7   Venue (1st leg)         41 non-null     object
#  8   Host city (1st leg)     41 non-null     object
#  9   Host country (1st leg)  41 non-null     object
#  10  Venue (2nd leg)         38 non-null     object
#  11  Host city (2nd leg)     38 non-null     object
#  12  Host country (2nd leg)  38 non-null     object
#  13  Attendance (1st leg)    6 non-null      float64
# ...

# %%
# Displaying number of titles by club:
uic.groupby('Season').first()['Winners'].value_counts().plot(kind = 'barh',
                                                                     figsize = (8, 16))
plt.ylabel(None)
plt.title('Breakdown of winners by Club', fontweight = 'bold')
plt.show()

# %%
# Displaying number of runners-up by club:
uic.groupby('Season').first()['Runners-up'].value_counts().plot(kind = 'barh',
                                                                     figsize = (8, 16))
plt.ylabel(None)
plt.title('Breakdown of runners-up by Club', fontweight = 'bold')
plt.show()

# %%
# Displaying number of titles by country:
uic.groupby('Season').first()['Winners country'].value_counts().plot(kind = 'barh',
                                                                     figsize = (8, 8))
plt.ylabel(None)
plt.title('Breakdown of winners by Country', fontweight = 'bold')
plt.show()

# %%
# Displaying number of runners-up by country:
uic.groupby('Season').first()['Runners-up country'].value_counts().plot(kind = 'barh',
                                                                     figsize = (8, 8))
plt.ylabel(None)
plt.title('Breakdown of runners-up by Country', fontweight = 'bold')
plt.show()

# %%
# Displaying the attendances of the 1st and 2nd leg matches by season:
plt.figure(figsize = (32,16))
plt.plot(uic['Season'], uic['Attendance (1st leg)'])
plt.plot(uic['Season'], uic['Attendance (2nd leg)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5ab78914fe41> in <cell line: 4>()
#       2 plt.figure(figsize = (32,16))
#       3 plt.plot(uic['Season'], uic['Attendance (1st leg)'])
# ----> 4 plt.plot(uic['Season'], uic['Attendance (2nd leg)'])
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
# Displaying the total attendances (1st and 2nd leg matches) by season:
plt.figure(figsize = (32,16))
plt.plot(uic['Season'], uic['Attendance (1st leg)'] + uic['Attendance (2nd leg)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     164     try:
# --> 165         result = func(left, right)
#     166     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     240             # error: "None" not callable
# --> 241             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     128     if result is None:
# --> 129         result = _evaluate_standard(op, op_str, a, b)
#     130
#
# ...

# %%
# Displaying the average attendances (1st and 2nd leg matches) by season:
plt.figure(figsize = (32,16))
plt.plot(uel['Season'], (uel['Attendance (1st leg)'] + uel['Attendance (2nd leg)']) / 2)
